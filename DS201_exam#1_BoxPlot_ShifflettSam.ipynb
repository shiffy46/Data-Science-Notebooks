# %%
import pandas as pd
data = pd.read_csv('Automobile_price_data_clean-f18.csv')
data1 = pd.DataFrame(data)

# %%
data1.boxplot(column = ['price'], by = ['body-style'], figsize=(15,10),fontsize=12,rot=45,showfliers=False)
