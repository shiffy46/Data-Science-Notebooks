# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from bokeh.io import show, output_notebook, output_file
from bokeh.plotting import figure

# %%
df = pd.read_csv("Lemonade_Lab10.csv")

# %%
df
# Out:
#        Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 0    7/1/16     Park     97      78           70        90   0.25
# 1    7/2/16     Park     98      67           72        90   0.25
# 2    7/3/16     Park    110      54           71       104   0.25
# 3    7/4/16    Beach    134      56           76        98   0.25
# 4    7/5/16    Beach    159      90           78       135   0.25
# 5    7/6/16    Beach    103      89           82        90   0.25
# 6    7/6/16    Beach    103      78           82        90   0.25
# 7    7/7/16    Beach    143     108           81       135   0.25
# 8    7/8/16    Beach    123      78           82       113   0.25
# 9    7/9/16    Beach    134      99           80       126   0.25
# 10  7/10/16    Beach    140      98           82       131   0.25
# 11  7/11/16    Beach    162     112           83       135   0.25
# 12  7/12/16    Beach    130      95           84        99   0.25
# 13  7/13/16    Beach    109      65           77        99   0.25
# 14  7/14/16    Beach    122      90           78       113   0.25
# 15  7/15/16    Beach     98      70           75       108   0.50
# 16  7/16/16    Beach     81      87           74        90   0.50
# 17  7/17/16    Beach    115     102           77       126   0.50
# 18  7/18/16     Park    131      99           81       122   0.50
# 19  7/19/16     Park    122      76           78       113   0.50
# 20  7/20/16     Park     71      41           70       109   0.50
# 21  7/21/16     Park     83      42           77        90   0.50
# 22  7/22/16     Park    112      78           80       108   0.50
# 23  7/23/16     Park    120      90           81       117   0.50
# 24  7/24/16     Park    121      87           82       117   0.50
# 25  7/25/16     Park    156     128           84       135   0.50
# 26  7/26/16     Park    176     139           83       158   0.35
# 27  7/27/16     Park    104      89           80        99   0.35
# 28  7/28/16     Park     96      78           82        90   0.35
# 29  7/29/16     Park    100      77           81        95   0.35
# ..      ...      ...    ...     ...          ...       ...    ...
# 33   8/2/16     Park     67     105           72       122   0.35
# 34   8/3/16     Park     77      98           71       113   0.35
# 35   8/4/16    Beach     99     144           76       109   0.35
# 36   8/5/16    Beach    118     123           78        90   0.35
# 37   8/6/16    Beach     69      76           82       108   0.35
# 38   8/7/16    Beach     69      56           82       117   0.35
# 39   8/8/16    Beach    101     100           81       117   0.25
# 40   8/9/16    Beach     86      89           82       135   0.25
# 41  8/10/16    Beach     95      78           80       158   0.25
# 42  8/11/16    Beach     98      67           82        99   0.25
# 43  8/12/16    Beach    120     102           83        90   0.25
# 44  8/13/16    Beach     95      86           84        95   0.25
# 45  8/14/16    Beach     75      67           77        81   0.25
# 46  8/15/16    Beach     85      78           78        68   0.25
# 47  8/16/16    Beach     62      78           75       135   0.25
# 48  8/17/16    Beach     50      49           74       113   0.25
# 49  8/18/16    Beach     76      78           77       126   0.25
# 50  8/19/16     Park     92      96           81       131   0.25
# 51  8/20/16     Park     85      78           78       135   0.25
# 52  8/21/16     Park     42      65           70        99   0.25
# 53  8/22/16     Park     50      61           77        99   0.25
# 54  8/23/16     Park     75      64           80       113   0.25
# 55  8/24/16     Park     82      76           81       108   0.50
# 56  8/25/16     Park     82      99           82        90   0.50
# 57  8/26/16     Park    113     101           84        90   0.50
# 58  8/27/16     Park    129     100           83        90   0.35
# 59  8/28/16     Park     68      56           80       104   0.35
# 60  8/29/16     Park     63      77           82        98   0.35
# 61  8/30/16     Park     66      90           81       135   0.35
# 62  8/31/16    Beach     57      65           82        90   0.35
#
# [63 rows x 7 columns]

# %%
p = figure(title="Lemon and Orange Sales by Temperature")

# %%
p.circle(x=df['Temperature'], y=df['Lemon'], size=10, alpha=0.5, color='green', legend='lemon')
p.triangle(x=df['Temperature'], y=df['Orange'], size=10, alpha=0.5, color='orange', legend='orange')
p.legend.location='top_left'
show(p)

# %%
grouped = df.groupby('Temperature')
lem = grouped['Lemon']

# %%
avg = lem.mean()

# %%
std = lem.std()

# %%
Tem = list(grouped.groups.keys())

# %%
Park = df[df['Location']=="Park"]

# %%
Beach = df[df['Location']=='Beach']

# %%
v = figure(title="Temperature Vs Lemon Sales (Park and Beach)")

# %%
v.vbar(x=Tem, bottom=avg-std, top=avg+std, width=0.8, fill_alpha=0.2, line_color=None, legend="Lemon Revenue 1 std")
v.circle(x=Beach['Temperature'], y=Beach['Lemon'], alpha=0.5, size=10, color='red', legend='Sales in Beach')
v.triangle(x=Park['Temperature'], y=Park['Lemon'], alpha=0.5, size=10, color='blue', legend='Sales in Park')
v.legend.location="top_left"
show(v)
