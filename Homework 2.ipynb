# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv("Lemonade2016-2.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 7 columns):
# Date           31 non-null object
# Location       32 non-null object
# Lemon          32 non-null int64
# Orange         32 non-null int64
# Temperature    32 non-null int64
# Leaflets       31 non-null float64
# Price          32 non-null float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 1.8+ KB

# %%
df.head()
# Out:
#        Date Location  Lemon  Orange  Temperature  Leaflets  Price  Sales  \
# 0  7/1/2016     Park     97      67           70      90.0   0.25    164
# 1  7/2/2016     Park     98      67           72      90.0   0.25    165
# 2  7/3/2016     Park    110      77           71     104.0   0.25    187
# 3  7/4/2016    Beach    134      99           76      98.0   0.25    233
# 4  7/5/2016    Beach    159     118           78     135.0   0.25    277
#
#    Revenue
# 0    41.00
# 1    41.25
# 2    46.75
# 3    58.25
# 4    69.25

# %%
df.loc[8,'Date'] = "7/8/2016"

# %%
df['Leaflets'].notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20    False
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# Name: Leaflets, dtype: bool

# %%
df['Leaflets'] = df['Leaflets'].fillna(round(df['Leaflets'].mean()))

# %%
df
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 0    7/1/2016     Park     97      67           70      90.0   0.25
# 1    7/2/2016     Park     98      67           72      90.0   0.25
# 2    7/3/2016     Park    110      77           71     104.0   0.25
# 3    7/4/2016    Beach    134      99           76      98.0   0.25
# 4    7/5/2016    Beach    159     118           78     135.0   0.25
# 5    7/6/2016    Beach    103      69           82      90.0   0.25
# 6    7/6/2016    Beach    103      69           82      90.0   0.25
# 7    7/7/2016    Beach    143     101           81     135.0   0.25
# 8    7/8/2016    Beach    123      86           82     113.0   0.25
# 9    7/9/2016    Beach    134      95           80     126.0   0.25
# 10  7/10/2016    Beach    140      98           82     131.0   0.25
# 11  7/11/2016    Beach    162     120           83     135.0   0.25
# 12  7/12/2016    Beach    130      95           84      99.0   0.25
# ...

# %%
df.drop_duplicates()
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 0    7/1/2016     Park     97      67           70      90.0   0.25
# 1    7/2/2016     Park     98      67           72      90.0   0.25
# 2    7/3/2016     Park    110      77           71     104.0   0.25
# 3    7/4/2016    Beach    134      99           76      98.0   0.25
# 4    7/5/2016    Beach    159     118           78     135.0   0.25
# 5    7/6/2016    Beach    103      69           82      90.0   0.25
# 7    7/7/2016    Beach    143     101           81     135.0   0.25
# 8    7/8/2016    Beach    123      86           82     113.0   0.25
# 9    7/9/2016    Beach    134      95           80     126.0   0.25
# 10  7/10/2016    Beach    140      98           82     131.0   0.25
# 11  7/11/2016    Beach    162     120           83     135.0   0.25
# 12  7/12/2016    Beach    130      95           84      99.0   0.25
# 13  7/13/2016    Beach    109      75           77      99.0   0.25
# ...

# %%
df.reset_index()
# Out:
#     index       Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 0       0   7/1/2016     Park     97      67           70      90.0   0.25
# 1       1   7/2/2016     Park     98      67           72      90.0   0.25
# 2       2   7/3/2016     Park    110      77           71     104.0   0.25
# 3       3   7/4/2016    Beach    134      99           76      98.0   0.25
# 4       4   7/5/2016    Beach    159     118           78     135.0   0.25
# 5       5   7/6/2016    Beach    103      69           82      90.0   0.25
# 6       6   7/6/2016    Beach    103      69           82      90.0   0.25
# 7       7   7/7/2016    Beach    143     101           81     135.0   0.25
# 8       8   7/8/2016    Beach    123      86           82     113.0   0.25
# 9       9   7/9/2016    Beach    134      95           80     126.0   0.25
# 10     10  7/10/2016    Beach    140      98           82     131.0   0.25
# ...

# %%
df['Sales'] = df['Lemon']+df['Orange']

# %%
df
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price  Sales
# 0    7/1/2016     Park     97      67           70      90.0   0.25    164
# 1    7/2/2016     Park     98      67           72      90.0   0.25    165
# 2    7/3/2016     Park    110      77           71     104.0   0.25    187
# 3    7/4/2016    Beach    134      99           76      98.0   0.25    233
# 4    7/5/2016    Beach    159     118           78     135.0   0.25    277
# 5    7/6/2016    Beach    103      69           82      90.0   0.25    172
# 6    7/6/2016    Beach    103      69           82      90.0   0.25    172
# 7    7/7/2016    Beach    143     101           81     135.0   0.25    244
# 8    7/8/2016    Beach    123      86           82     113.0   0.25    209
# 9    7/9/2016    Beach    134      95           80     126.0   0.25    229
# 10  7/10/2016    Beach    140      98           82     131.0   0.25    238
# ...

# %%
df['Revenue'] = df['Sales']*df['Price']
df
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price  Sales  \
# 0    7/1/2016     Park     97      67           70      90.0   0.25    164
# 1    7/2/2016     Park     98      67           72      90.0   0.25    165
# 2    7/3/2016     Park    110      77           71     104.0   0.25    187
# 3    7/4/2016    Beach    134      99           76      98.0   0.25    233
# 4    7/5/2016    Beach    159     118           78     135.0   0.25    277
# 5    7/6/2016    Beach    103      69           82      90.0   0.25    172
# 6    7/6/2016    Beach    103      69           82      90.0   0.25    172
# 7    7/7/2016    Beach    143     101           81     135.0   0.25    244
# 8    7/8/2016    Beach    123      86           82     113.0   0.25    209
# 9    7/9/2016    Beach    134      95           80     126.0   0.25    229
# 10  7/10/2016    Beach    140      98           82     131.0   0.25    238
# ...

# %%
df.plot.scatter(x=['Leaflets'],y=['Sales'])

# %%
df.hist(column = ['Revenue'], bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000066BD5C0>]],
#       dtype=object)

# %%
df.boxplot(by=['Location'], column=['Sales'])

# %%
df.boxplot(by=['Location'], column=['Sales'])

# %%
import seaborn as sns

# %%
ax = sns.boxplot(x='Location', y = 'Sales', data = df, palette='Set3')

# %%
data1 = df['Temperature'] >= 75
df[data1]
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price  Sales  \
# 3    7/4/2016    Beach    134      99           76      98.0   0.25    233
# 4    7/5/2016    Beach    159     118           78     135.0   0.25    277
# 5    7/6/2016    Beach    103      69           82      90.0   0.25    172
# 6    7/6/2016    Beach    103      69           82      90.0   0.25    172
# 7    7/7/2016    Beach    143     101           81     135.0   0.25    244
# 8    7/8/2016    Beach    123      86           82     113.0   0.25    209
# 9    7/9/2016    Beach    134      95           80     126.0   0.25    229
# 10  7/10/2016    Beach    140      98           82     131.0   0.25    238
# 11  7/11/2016    Beach    162     120           83     135.0   0.25    282
# 12  7/12/2016    Beach    130      95           84      99.0   0.25    225
# 13  7/13/2016    Beach    109      75           77      99.0   0.25    184
# ...

# %%
ax1 = sns.boxplot(x='Location', y = 'Sales', data = df[data1], palette='Set3')

# %%
data2 = df[['Revenue','Temperature','Leaflets','Location']]
data2
# Out:
#     Revenue  Temperature  Leaflets Location
# 0     41.00           70      90.0     Park
# 1     41.25           72      90.0     Park
# 2     46.75           71     104.0     Park
# 3     58.25           76      98.0    Beach
# 4     69.25           78     135.0    Beach
# 5     43.00           82      90.0    Beach
# 6     43.00           82      90.0    Beach
# 7     61.00           81     135.0    Beach
# 8     52.25           82     113.0    Beach
# 9     57.25           80     126.0    Beach
# 10    59.50           82     131.0    Beach
# 11    70.50           83     135.0    Beach
# 12    56.25           84      99.0    Beach
# 13    46.00           77      99.0    Beach
# 14    51.75           78     113.0    Beach
# 15    80.00           75     108.0    Beach
# 16    65.50           74      90.0    Beach
# 17    95.50           77     126.0    Beach
# 18   111.50           81     122.0     Park
# 19   103.50           78     113.0     Park
# ...

# %%
sns.pairplot(data2, hue='Location')
